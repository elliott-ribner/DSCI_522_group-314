# %%
# %%bash
# jupyter nbconvert --execute  final_report.ipynb --to latex --template  final_report.tplx
# #latex final_report.tex
# bibtex final_report.aux
# pdflatex final_report.tex
# Out:
# This is BibTeX, Version 0.99d (TeX Live 2019)
# The top-level auxiliary file: final_report.aux
# The style file: plain.bst
# Database file #1: ref.bib
# Warning--I didn't find a database entry for "Python"
# Warning--I didn't find a database entry for "Dua:2019"
# (There were 2 warnings)
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./final_report.tex
# LaTeX2e <2018-12-01>
# (/usr/local/texlive/2019basic/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2018/09/03 v1.4i Standard LaTeX document class
# (/usr/local/texlive/2019basic/texmf-dist/tex/latex/base/size11.clo))
# (/usr/local/texlive/2019basic/texmf-dist/tex/latex/tcolorbox/tcolorbox.sty
# (/usr/local/texlive/2019basic/texmf-dist/tex/latex/pgf/basiclayer/pgf.sty
# (/usr/local/texlive/2019basic/texmf-dist/tex/latex/pgf/utilities/pgfrcs.sty
# ...
